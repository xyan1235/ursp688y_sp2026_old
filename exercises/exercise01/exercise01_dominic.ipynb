# %% [markdown]
# Urban Data Science & Smart Cities <br>
# URSP688Y Spring 2026<br>
# Instructor: Chester Harvey <br>
# Urban Studies & Planning <br>
# National Center for Smart Growth <br>
# University of Maryland

# %% [markdown]
# # Exercise01

# %% [markdown]
# ## Problem
# Montgomery County gets many requests for service from its agencies. The County wants to understand more about what types of requests are most common and where they come from.
#
# Please use your new Python skills and data about requests in January to help the County understand:
# 1. How many times did each type of request get made?
# 2. How many times did requests get made from each city?
#
# First write pseudocode to answer these questions. Then write a Python program around the pseudocode.
#
# Optional: See if you can write a function to package your analysis and return results. How can you use arguments to generalize the function so it can answer either of the questions above?
#
# ## Data
#
# Below is a dictionary with a few hundred records of service requests from a dataset available on Montgomery County's [Open Data Portal](https://data.montgomerycountymd.gov/Community-Recreation/Agency-Service-Requests/5diu-yj9e/about_data). I queried requests made so-far in 2026 and stored them in a basic data structure called json (JavaScript Object Notation).
#
# As you can see, the County got a lot of requests in less than a month!
#
# ## Hints
# - There are many possible ways to program this. don't worry about finding the "right" or "best" one. Figure out one way that works, and then refine it if you see opportunities.
# - `for` loops may be useful for iterating through lists and dictionaries.
# - You may want to define one or more variables and update them on each loop to keep track of counts or things your has 'seen' in the data.
# - `service_requests` is a list with dictionaries nested inside it--a list of dictionaries.
# - To access the dictionaries inside the list, you may want to use nested loops: one loop inside another loop.
#
# ## Submitting
# 1. Make a new branch in your fork of the course repository.
# 2. Save a copy of your notebook with your first name as an underscored suffix (e.g., `exercise01_chester.ipynb`).
# 3. Commit and push your saved notebook to your fork on Github.
# 4. Make a pull request to the base course repository.

# %%
# Import dependencies (code you need that's stored outside this file)
import json

# %%
# Load the service call data from the json file
with open('service_requests.json', 'r') as json_file:
    service_requests = json.load(json_file)

# %%
service_requests
# Out:
# [{'Service Request Number': 200138064,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/01/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '804',
#   'Pre-direction': nan,
#   'Street name of work location': 'LOWANDER',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138065,
#   'Request Type': 'B12',
#   'Description': 'COMMERCIAL BUILDING VIOLATION',
#   'Request Date': '01/01/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'BERNA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '11110',
#   'Pre-direction': nan,
#   'Street name of work location': 'MEDICAL CENTER',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138066,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '01/01/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '12029',
#   'Pre-direction': nan,
#   'Street name of work location': 'GEORGIA',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138063,
#   'Request Type': 'Z14',
#   'Description': 'ZONING-RES-COMMERCIAL VEHICLES, RES ZONE',
#   'Request Date': '01/01/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GUILM',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '11201',
#   'Pre-direction': nan,
#   'Street name of work location': 'BETHESDA CHURCH',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138067,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/02/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '804',
#   'Pre-direction': nan,
#   'Street name of work location': 'LOWANDER',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138068,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/02/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '722',
#   'Pre-direction': nan,
#   'Street name of work location': 'ERIE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'TAKOMA PARK',
#   'State': 'MD',
#   'ZIP code': 20912.0},
#  {'Service Request Number': 200138069,
#   'Request Type': 'RW2',
#   'Description': 'NO D/W PERMIT (D/W CONSTRUCTED W/O PERMIT)',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FOWLE',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '8613',
#   'Pre-direction': nan,
#   'Street name of work location': 'HARTSDALE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20817.0},
#  {'Service Request Number': 200138081,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/03/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': 'LOVEL',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '10530',
#   'Pre-direction': nan,
#   'Street name of work location': 'WESTLAKE',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20817.0},
#  {'Service Request Number': 200138082,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/03/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': 'LOVEL',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '1380',
#   'Pre-direction': nan,
#   'Street name of work location': 'PICCARD',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138079,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': 'Montgomery Village',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138080,
#   'Request Type': 'Z22',
#   'Description': 'ZONING-COM-LANDSCAPING,SCREENING,LIGHT',
#   'Request Date': '01/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': 'Autumn Lake Healthcare at Oakview facility.',
#   'Street Number': '2700',
#   'Pre-direction': nan,
#   'Street name of work location': 'BARKER',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138078,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '01/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MCGHK',
#   'Inspection Date': nan,
#   'Location': 'Construyeron un cuarto en la sala tapando la salida hacia las escaleras  necesito que vengan no tienen permiso del condado para esa Construcci�n. La direcci�n es 3740 bel pre rd silver Spring MD 20906',
#   'Street Number': '3740',
#   'Pre-direction': nan,
#   'Street name of work location': 'BEL PRE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138095,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9274',
#   'Pre-direction': nan,
#   'Street name of work location': 'GAITHER',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20877.0},
#  {'Service Request Number': 200138097,
#   'Request Type': 'Z14',
#   'Description': 'ZONING-RES-COMMERCIAL VEHICLES, RES ZONE',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GUILM',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '11201',
#   'Pre-direction': nan,
#   'Street name of work location': 'BETHESDA CHURCH',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138096,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'WILKD',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '2712',
#   'Pre-direction': nan,
#   'Street name of work location': 'BLAINE',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'CHEVY CHASE',
#   'State': 'MD',
#   'ZIP code': 20815.0},
#  {'Service Request Number': 200138099,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9215',
#   'Pre-direction': nan,
#   'Street name of work location': 'WORTH',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138106,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WILLV',
#   'Inspector': 'WILLV',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9910',
#   'Pre-direction': nan,
#   'Street name of work location': 'KEY WEST',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138108,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WILLV',
#   'Inspector': 'WILLV',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '16707',
#   'Pre-direction': nan,
#   'Street name of work location': 'CRABBS BRANCH',
#   'Street Suffix': 'WAY',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20855.0},
#  {'Service Request Number': 200138107,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '206',
#   'Pre-direction': 'E',
#   'Street name of work location': 'WAYNE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138109,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': 'Frozen Fur Hydrant 16601 George Washington drive',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138110,
#   'Request Type': 'RW1',
#   'Description': 'ROW VIOLATIONS',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LATHN',
#   'Inspection Date': nan,
#   'Location': 'Locations:  (1) on sidewalk along Hornbeam Drive, near entrance to Flower Valley Park; (2) along sidewalk on Wild Rose street, near intersection with Sunflower Drive (to left of FVES); (3) intersection of Sunflower Drive & Westbury.',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138111,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '01/05/2026',
#   'Taken By': 'CLARI',
#   'Inspector': 'GILBC',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '9436',
#   'Pre-direction': nan,
#   'Street name of work location': 'DAMASCUS',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138112,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '01/06/2026',
#   'Location': 'The Noor Center on Boland Farm Road, Germantown, MD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138062,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/01/2026',
#   'Taken By': 'BARNB',
#   'Inspector': 'BARNB',
#   'Inspection Date': nan,
#   'Location': 'North Bethesda Market',
#   'Street Number': '11418',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROCKVILLE',
#   'Street Suffix': 'PIKE',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138070,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/02/2026',
#   'Taken By': 'BARNB',
#   'Inspector': 'BARNB',
#   'Inspection Date': nan,
#   'Location': 'North Bethesda Market, Bldg. A',
#   'Street Number': '11418',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROCKVILLE',
#   'Street Suffix': 'PIKE',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138071,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'Countryside commmunity, News Lane and Countryside Dr.',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138075,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/02/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '7301',
#   'Pre-direction': nan,
#   'Street name of work location': 'HADLEY FARMS',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20879.0},
#  {'Service Request Number': 200138077,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/03/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '3301',
#   'Pre-direction': nan,
#   'Street name of work location': 'HEWITT',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138086,
#   'Request Type': 'Z25',
#   'Description': 'FENCES',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '3924',
#   'Pre-direction': nan,
#   'Street name of work location': 'HALSEY',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'KENSINGTON',
#   'State': 'MD',
#   'ZIP code': 20895.0},
#  {'Service Request Number': 200138072,
#   'Request Type': 'WR1',
#   'Description': 'SEDIMENT CONTROL ENVIRONMENTAL',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'ODONJ',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '20500',
#   'Pre-direction': nan,
#   'Street name of work location': 'BOLAND FARM',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20876.0},
#  {'Service Request Number': 200138073,
#   'Request Type': 'RW4',
#   'Description': 'OBSTRUCTION IN ROW (DUMPSTER, MONUMENT MAILBOX & TREES)',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LATHN',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5414',
#   'Pre-direction': nan,
#   'Street name of work location': 'PARKVALE',
#   'Street Suffix': 'TER',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20853.0},
#  {'Service Request Number': 200138076,
#   'Request Type': 'WR1',
#   'Description': 'SEDIMENT CONTROL ENVIRONMENTAL',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'THRASJ',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '2760',
#   'Pre-direction': nan,
#   'Street name of work location': 'LINDEN',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20910.0},
#  {'Service Request Number': 200138074,
#   'Request Type': 'FM01',
#   'Description': 'FIRE ALARM ACTIVATION FOLLOW UP',
#   'Request Date': '01/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': 'Failure to update fire protection systems (40-year high-rises; 55+ age residents) incl. painting corroded/expired dry sprinkler system at 15115 Interlachen Dr, Silver Spring, MD 20906, and 15100 Interlachen Dr, Silver Spring, MD 20906.',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138094,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GARCW',
#   'Inspection Date': '01/14/2026',
#   'Location': nan,
#   'Street Number': '15321',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH ORCHARD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138125,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/06/2026',
#   'Taken By': 'AREIZ',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '8709',
#   'Pre-direction': nan,
#   'Street name of work location': 'SECOND',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138126,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/06/2026',
#   'Taken By': 'BARNB',
#   'Inspector': 'BARNB',
#   'Inspection Date': nan,
#   'Location': 'Poolesville Memorial Church',
#   'Street Number': '17821',
#   'Pre-direction': nan,
#   'Street name of work location': 'ELGIN',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'POOLESVILLE',
#   'State': 'MD',
#   'ZIP code': 20837.0},
#  {'Service Request Number': 200138127,
#   'Request Type': 'B12',
#   'Description': 'COMMERCIAL BUILDING VIOLATION',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'BERNA',
#   'Inspection Date': nan,
#   'Location': 'Across the street from my home at 2007 Henson Norris, Rockville, MD 20850. New Construction Townhomes/Condos being built by EYA/Pulte (https://www.farmsteaddistrict.com/)',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138128,
#   'Request Type': 'DA10',
#   'Description': 'DAMAGE ASSESSMENT',
#   'Request Date': '01/06/2026',
#   'Taken By': 'SHUPP',
#   'Inspector': 'SHUPP',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '1603',
#   'Pre-direction': nan,
#   'Street name of work location': 'NOYES',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20910.0},
#  {'Service Request Number': 200138129,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '01/06/2026',
#   'Location': 'The Noor Center on Boland Farm Road, Germantown, MD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138130,
#   'Request Type': 'S10',
#   'Description': 'NO PERMIT FOR SIGN',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MEJIR',
#   'Inspection Date': '01/07/2026',
#   'Location': 'Northeast corner of Steeple Road and Hopkins Road in Germantown. Near 13851 Hopkins Rd, Germantown, MD 20874.',
#   'Street Number': '13851',
#   'Pre-direction': nan,
#   'Street name of work location': 'HOPKINS',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20874.0},
#  {'Service Request Number': 200138131,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/06/2026',
#   'Taken By': 'SUDIK',
#   'Inspector': 'SUDIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5159',
#   'Pre-direction': nan,
#   'Street name of work location': 'POOKS HILL',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138132,
#   'Request Type': 'LD1',
#   'Description': 'WSSC work',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'THRASJ',
#   'Inspection Date': '01/07/2026',
#   'Location': 'At creek under walking bridge at intersection of East Melbourne Avenue and Wilmer Street in Silver Spring, MD  20901',
#   'Street Number': '305',
#   'Pre-direction': 'E',
#   'Street name of work location': 'MELBOURNE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138133,
#   'Request Type': 'B11',
#   'Description': 'RESIDENTIAL BUILDING VIOLATION',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WILLH',
#   'Inspector': 'WILLH',
#   'Inspection Date': '01/05/2026',
#   'Location': nan,
#   'Street Number': '8116',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROANOKE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'TAKOMA PARK',
#   'State': 'MD',
#   'ZIP code': 20912.0},
#  {'Service Request Number': 200138135,
#   'Request Type': 'Z13',
#   'Description': 'ZONING-RES-ANIMALS IN RESIDENTIAL ZONE',
#   'Request Date': '01/06/2026',
#   'Taken By': 'LUNDC',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '801',
#   'Pre-direction': nan,
#   'Street name of work location': 'WINHALL',
#   'Street Suffix': 'WAY',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20904.0},
#  {'Service Request Number': 200138134,
#   'Request Type': 'WR3',
#   'Description': 'SEDIMENT CONTROL NUISANCE',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'BOWEB',
#   'Inspection Date': nan,
#   'Location': '5208   Edgemoor LN     MD',
#   'Street Number': '5208',
#   'Pre-direction': nan,
#   'Street name of work location': 'EDGEMOOR',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138139,
#   'Request Type': 'RW5',
#   'Description': 'UTILITY PATCH (PATCH LOW)',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'STAUJ',
#   'Inspection Date': nan,
#   'Location': 'the patch of grass between westbard ave and ridgefield road',
#   'Street Number': '5153',
#   'Pre-direction': nan,
#   'Street name of work location': 'WESTBARD',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20816.0},
#  {'Service Request Number': 200138140,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WILLV',
#   'Inspector': 'WILLV',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9601',
#   'Pre-direction': nan,
#   'Street name of work location': 'BLACKWELL',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138141,
#   'Request Type': 'FM02',
#   'Description': 'FIRE PROTECTION AGREEMENT',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': '1014   Debeck DR     MD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138142,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/06/2026',
#   'Taken By': 'LEWIK',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': 'Wheaton Park Shopping Plaza - 11915-11941',
#   'Street Number': '11941',
#   'Pre-direction': nan,
#   'Street name of work location': 'GEORGIA',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138145,
#   'Request Type': 'S',
#   'Description': 'SIGNS',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': 'Traffic island on Saul Road at Cedar Lane',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138138,
#   'Request Type': 'Z28',
#   'Description': 'BUILDING HEIGHT',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'CALLB',
#   'Inspection Date': nan,
#   'Location': '5821   Highland Drive DR  W   MD',
#   'Street Number': '5821',
#   'Pre-direction': nan,
#   'Street name of work location': 'HIGHLAND',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'CHEVY CHASE',
#   'State': 'MD',
#   'ZIP code': 20815.0},
#  {'Service Request Number': 200138144,
#   'Request Type': 'S',
#   'Description': 'SIGNS',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'CARYL',
#   'Inspection Date': nan,
#   'Location': 'Bells Mill elementary (sidewalk & bus loop)\nFallsmead elementary school (sidewalks)\nLuxmanor elementary school (sidewalk, bus loop, parking lot)',
#   'Street Number': '1800',
#   'Pre-direction': nan,
#   'Street name of work location': 'GREENPLACE',
#   'Street Suffix': 'TER',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138143,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/06/2026',
#   'Taken By': 'AREIZ',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': 'Second Avenue Plaza Office Condo',
#   'Street Number': '8609',
#   'Pre-direction': nan,
#   'Street name of work location': 'SECOND',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20910.0},
#  {'Service Request Number': 200138085,
#   'Request Type': 'Z14',
#   'Description': 'ZONING-RES-COMMERCIAL VEHICLES, RES ZONE',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '3711',
#   'Pre-direction': nan,
#   'Street name of work location': 'FAIRLY',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138087,
#   'Request Type': 'FM02',
#   'Description': 'FIRE PROTECTION AGREEMENT',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': 'Rockville Sports Arena',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138089,
#   'Request Type': 'Z25',
#   'Description': 'FENCES',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '3924',
#   'Pre-direction': nan,
#   'Street name of work location': 'HALSEY',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'KENSINGTON',
#   'State': 'MD',
#   'ZIP code': 20895.0},
#  {'Service Request Number': 200138083,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LEATT',
#   'Inspection Date': nan,
#   'Location': '11341/11339 King George Drive',
#   'Street Number': '11341',
#   'Pre-direction': nan,
#   'Street name of work location': 'KING GEORGE',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138084,
#   'Request Type': 'Z13',
#   'Description': 'ZONING-RES-ANIMALS IN RESIDENTIAL ZONE',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GOMEI',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '22931',
#   'Pre-direction': nan,
#   'Street name of work location': 'OLD HUNDRED',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DICKERSON',
#   'State': 'MD',
#   'ZIP code': 20842.0},
#  {'Service Request Number': 200138088,
#   'Request Type': 'S',
#   'Description': 'SIGNS',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': 'Arcola Avenue & Lamberton Drive at the island as you enter Kemp Mill Estates.',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138090,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GARCW',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '15004',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH ORCHARD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138100,
#   'Request Type': 'Z28',
#   'Description': 'BUILDING HEIGHT',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'CALLB',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5',
#   'Pre-direction': nan,
#   'Street name of work location': 'CLEVELAND',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138148,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'CAIN COMMONS',
#   'Street Number': '25104',
#   'Pre-direction': nan,
#   'Street name of work location': 'RIDGE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138149,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'CAIN COMMONS',
#   'Street Number': '25104',
#   'Pre-direction': nan,
#   'Street name of work location': 'RIDGE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138150,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'CAIN COMMONS',
#   'Street Number': '25104',
#   'Pre-direction': nan,
#   'Street name of work location': 'RIDGE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138151,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'LOVEL',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'CAIN COMMONS',
#   'Street Number': '25104',
#   'Pre-direction': nan,
#   'Street name of work location': 'RIDGE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'DAMASCUS',
#   'State': 'MD',
#   'ZIP code': 20872.0},
#  {'Service Request Number': 200138153,
#   'Request Type': 'RW1',
#   'Description': 'ROW VIOLATIONS',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'SIMMG',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5200',
#   'Pre-direction': nan,
#   'Street name of work location': 'CROSSFIELD',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138155,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '3012',
#   'Pre-direction': nan,
#   'Street name of work location': 'MILES',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BURTONSVILLE',
#   'State': 'MD',
#   'ZIP code': 20866.0},
#  {'Service Request Number': 200138154,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'STAUJ',
#   'Inspector': 'STAUJ',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5014',
#   'Pre-direction': nan,
#   'Street name of work location': 'RODMAN',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20816.0},
#  {'Service Request Number': 200138158,
#   'Request Type': 'RW1',
#   'Description': 'ROW VIOLATIONS',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LEATT',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '4919',
#   'Pre-direction': nan,
#   'Street name of work location': 'MACON',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138152,
#   'Request Type': 'RW1',
#   'Description': 'ROW VIOLATIONS',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LATHN',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5200',
#   'Pre-direction': nan,
#   'Street name of work location': 'CROSSFIELD',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138091,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GARCW',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '15004',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH ORCHARD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138162,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'NICHO',
#   'Inspection Date': nan,
#   'Location': 'corner of Buckingham Dr & Linton St',
#   'Street Number': '905',
#   'Pre-direction': nan,
#   'Street name of work location': 'BUCKINGHAM',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20901.0},
#  {'Service Request Number': 200138163,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'BARNB',
#   'Inspector': 'BARNB',
#   'Inspection Date': nan,
#   'Location': 'Resiliency Work',
#   'Street Number': '19733',
#   'Pre-direction': nan,
#   'Street name of work location': 'EXECUTIVE PARK',
#   'Street Suffix': 'CIR',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20874.0},
#  {'Service Request Number': 200138164,
#   'Request Type': 'Z14',
#   'Description': 'ZONING-RES-COMMERCIAL VEHICLES, RES ZONE',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MEJIR',
#   'Inspection Date': '01/07/2026',
#   'Location': nan,
#   'Street Number': '12148',
#   'Pre-direction': nan,
#   'Street name of work location': 'ISLAND VIEW',
#   'Street Suffix': 'CIR',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20874.0},
#  {'Service Request Number': 200138165,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WILLV',
#   'Inspector': 'WILLV',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '10001',
#   'Pre-direction': nan,
#   'Street name of work location': 'VANDERBILT',
#   'Street Suffix': 'CIR',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138166,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MOMEE',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5409',
#   'Pre-direction': nan,
#   'Street name of work location': 'GOLF',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138170,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'non-traffic light intersection of Needwood Road and Redland Road',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138092,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GARCW',
#   'Inspection Date': '01/12/2026',
#   'Location': nan,
#   'Street Number': '15001',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH ORCHARD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138167,
#   'Request Type': 'RW5',
#   'Description': 'UTILITY PATCH (PATCH LOW)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MOMEE',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9512',
#   'Pre-direction': nan,
#   'Street name of work location': 'FALLS BRIDGE',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'POTOMAC',
#   'State': 'MD',
#   'ZIP code': 20854.0},
#  {'Service Request Number': 200138168,
#   'Request Type': 'RW5',
#   'Description': 'UTILITY PATCH (PATCH LOW)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MOMEE',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '6',
#   'Pre-direction': nan,
#   'Street name of work location': 'SOTWEED',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'POTOMAC',
#   'State': 'MD',
#   'ZIP code': 20854.0},
#  {'Service Request Number': 200138169,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LATHN',
#   'Inspection Date': nan,
#   'Location': 'non-traffic light intersection of Needwood Road and Redland Road',
#   'Street Number': '16219',
#   'Pre-direction': nan,
#   'Street name of work location': 'REDLAND',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20855.0},
#  {'Service Request Number': 200138098,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/05/2026',
#   'Taken By': 'PATTE',
#   'Inspector': 'PATTE',
#   'Inspection Date': nan,
#   'Location': 'Willow Manor at Fairland',
#   'Street Number': '13605',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROBEY',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20904.0},
#  {'Service Request Number': 200138101,
#   'Request Type': 'Z22',
#   'Description': 'ZONING-COM-LANDSCAPING,SCREENING,LIGHT',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '2700',
#   'Pre-direction': nan,
#   'Street name of work location': 'BARKER',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138102,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FCCSR',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '16601',
#   'Pre-direction': nan,
#   'Street name of work location': 'GEORGE WASHINGTON',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20853.0},
#  {'Service Request Number': 200138103,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'STAUJ',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '6313',
#   'Pre-direction': nan,
#   'Street name of work location': 'DAHLONEGA',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20816.0},
#  {'Service Request Number': 200138104,
#   'Request Type': 'RW2',
#   'Description': 'NO D/W PERMIT (D/W CONSTRUCTED W/O PERMIT)',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LEFER',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '16608',
#   'Pre-direction': 'S',
#   'Street name of work location': 'WESTLAND',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20877.0},
#  {'Service Request Number': 200138105,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/05/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': '9001   Schuyler RD  E   MD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138122,
#   'Request Type': 'WR3',
#   'Description': 'SEDIMENT CONTROL NUISANCE',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GRIFF',
#   'Inspection Date': '01/06/2026',
#   'Location': nan,
#   'Street Number': '11308',
#   'Pre-direction': nan,
#   'Street name of work location': 'STRYVER',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20878.0},
#  {'Service Request Number': 200138124,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '01/06/2026',
#   'Taken By': 'LEWIK',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5212',
#   'Pre-direction': nan,
#   'Street name of work location': 'DANBURY',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138137,
#   'Request Type': 'B11',
#   'Description': 'RESIDENTIAL BUILDING VIOLATION',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'WILLH',
#   'Inspection Date': '01/07/2026',
#   'Location': nan,
#   'Street Number': '8116',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROANOKE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'TAKOMA PARK',
#   'State': 'MD',
#   'ZIP code': 20912.0},
#  {'Service Request Number': 200138147,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '01/06/2026',
#   'Taken By': 'LEWIK',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': 'AVA Wheaton',
#   'Street Number': '2425',
#   'Pre-direction': nan,
#   'Street name of work location': 'BLUERIDGE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138093,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/04/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'GARCW',
#   'Inspection Date': '01/12/2026',
#   'Location': '14917 Peach Orchard Rd. Silver Spring MD 20905',
#   'Street Number': '14917',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH ORCHARD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138123,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/06/2026',
#   'Taken By': 'LEWIK',
#   'Inspector': 'LEWIK',
#   'Inspection Date': nan,
#   'Location': 'Parkway Plaza & Associates',
#   'Street Number': '10410',
#   'Pre-direction': nan,
#   'Street name of work location': 'KENSINGTON',
#   'Street Suffix': 'PKWY',
#   'Post-direction': nan,
#   'City': 'KENSINGTON',
#   'State': 'MD',
#   'ZIP code': 20895.0},
#  {'Service Request Number': 200138146,
#   'Request Type': 'Z28',
#   'Description': 'BUILDING HEIGHT',
#   'Request Date': '01/06/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'CALLB',
#   'Inspection Date': '01/08/2026',
#   'Location': 'New house construction.',
#   'Street Number': '5',
#   'Pre-direction': nan,
#   'Street name of work location': 'CLEVELAND',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138204,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '11131',
#   'Pre-direction': nan,
#   'Street name of work location': 'SCHUYLKILL',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0},
#  {'Service Request Number': 200138205,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'NICHO',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '7415',
#   'Pre-direction': nan,
#   'Street name of work location': 'WYNDALE',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'CHEVY CHASE',
#   'State': 'MD',
#   'ZIP code': 20815.0},
#  {'Service Request Number': 200138206,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/09/2026',
#   'Taken By': 'POLIC',
#   'Inspector': 'POLIC',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5121',
#   'Pre-direction': nan,
#   'Street name of work location': 'NORBECK',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20853.0},
#  {'Service Request Number': 200138161,
#   'Request Type': 'RW1',
#   'Description': 'ROW VIOLATIONS',
#   'Request Date': '01/07/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MELTM',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '12820',
#   'Pre-direction': nan,
#   'Street name of work location': 'CIRCLE',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138207,
#   'Request Type': 'WR1',
#   'Description': 'SEDIMENT CONTROL ENVIRONMENTAL',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FAIRJ',
#   'Inspection Date': '01/12/2026',
#   'Location': nan,
#   'Street Number': '24400',
#   'Pre-direction': nan,
#   'Street name of work location': 'PEACH TREE',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'CLARKSBURG',
#   'State': 'MD',
#   'ZIP code': 20871.0},
#  {'Service Request Number': 200138203,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'MOORE',
#   'Inspection Date': '01/12/2026',
#   'Location': nan,
#   'Street Number': '1518',
#   'Pre-direction': nan,
#   'Street name of work location': 'GRIDLEY',
#   'Street Suffix': 'LN',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138202,
#   'Request Type': 'RW5',
#   'Description': 'UTILITY PATCH (PATCH LOW)',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'FOWLE',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '5616',
#   'Pre-direction': nan,
#   'Street name of work location': 'GLENWOOD',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20817.0},
#  {'Service Request Number': 200138201,
#   'Request Type': 'Z30',
#   'Description': 'FRONT YARD PARKING',
#   'Request Date': '01/09/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'CARYL',
#   'Inspection Date': '01/12/2026',
#   'Location': nan,
#   'Street Number': '7518',
#   'Pre-direction': nan,
#   'Street name of work location': 'FILBERT',
#   'Street Suffix': 'TER',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20879.0},
#  {'Service Request Number': 200138159,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/07/2026',
#   'Taken By': 'BARNB',
#   'Inspector': 'BARNB',
#   'Inspection Date': nan,
#   'Location': 'Clarksburg Church',
#   'Street Number': '22820',
#   'Pre-direction': nan,
#   'Street name of work location': 'FREDERICK',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'CLARKSBURG',
#   'State': 'MD',
#   'ZIP code': 20871.0},
#  {'Service Request Number': 200138179,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '01/08/2026',
#   'Taken By': 'SCHRA',
#   'Inspector': 'SCHRA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '930',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROSE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
# ...
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20817.0},
#  {'Service Request Number': 200138565,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '02/01/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'WILLH',
#   'Inspection Date': '02/02/2026',
#   'Location': nan,
#   'Street Number': '14309',
#   'Pre-direction': nan,
#   'Street name of work location': 'STILTON',
#   'Street Suffix': 'CIR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138566,
#   'Request Type': 'B10',
#   'Description': 'NO BUILDING PERMIT',
#   'Request Date': '02/01/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EBERH',
#   'Inspection Date': '02/03/2026',
#   'Location': nan,
#   'Street Number': '14309',
#   'Pre-direction': nan,
#   'Street name of work location': 'STILTON',
#   'Street Suffix': 'CIR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20905.0},
#  {'Service Request Number': 200138581,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': 'White church on Lockwood drive',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138582,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': '8628 Chateau Dr, Rockville, MD 20854 (Behind property/flood zone)',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138602,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'SUDIK',
#   'Inspector': 'SUDIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '13069',
#   'Pre-direction': nan,
#   'Street name of work location': 'WISTERIA',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20874.0},
#  {'Service Request Number': 200138603,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'SUDIK',
#   'Inspector': 'SUDIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '15306',
#   'Pre-direction': nan,
#   'Street name of work location': 'DIAMOND COVE',
#   'Street Suffix': 'TER',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20850.0},
#  {'Service Request Number': 200138604,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/02/2026',
#   'Taken By': 'SUDIK',
#   'Inspector': 'SUDIK',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '10323',
#   'Pre-direction': nan,
#   'Street name of work location': 'OLD GEORGETOWN',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138605,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': 'Forest Glen HOA - Silver spring\nForest preserve areas adjacent to townhouses',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138606,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': 'North Creek Place Condominiums Bauer Drive Rockville MD 20853',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138607,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': '10508 Hutting Pl Silver Spring MD 209002 - Never ever in my 10 years I live in this neighbor this owner have not cleared their sidewalk.\n2518 Plyers Mill Rd Silver Spring MD 20902\n2520 Plyers Mill Rd Silver Spring MD 20902',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138608,
#   'Request Type': 'FM03',
#   'Description': 'EXTERNAL COMPLAINT FOLLOW UP',
#   'Request Date': '02/03/2026',
#   'Taken By': 'TOTHS',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '6921',
#   'Pre-direction': nan,
#   'Street name of work location': 'CLARENDON',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138609,
#   'Request Type': 'HO10',
#   'Description': 'HOME OCCUPATION-VEHICLE REPAIR',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': 'In the front yard at 3813 Greenly ST',
#   'Street Number': '3813',
#   'Pre-direction': nan,
#   'Street name of work location': 'GREENLY',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138610,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': '3333   Spartan RD     MD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138611,
#   'Request Type': 'B12',
#   'Description': 'COMMERCIAL BUILDING VIOLATION',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'BRISS',
#   'Inspection Date': nan,
#   'Location': '2647   University BLVD  W   MD',
#   'Street Number': '2647',
#   'Pre-direction': nan,
#   'Street name of work location': 'UNIVERSITY',
#   'Street Suffix': 'BLVD',
#   'Post-direction': 'W',
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20902.0},
#  {'Service Request Number': 200138612,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LEFER',
#   'Inspection Date': nan,
#   'Location': 'Along the driveway to my house at the end of Halterman rd.',
#   'Street Number': '24811',
#   'Pre-direction': nan,
#   'Street name of work location': 'HALTERMAN',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20882.0},
#  {'Service Request Number': 200138613,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': '3511 University Ave, Kensington Md.',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138614,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': '18625 Mooney Dr BLOCKING THE ROAD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138615,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': '02/03/2026',
#   'Location': '18625 Mooney Dr BLOCKING THE ROAD',
#   'Street Number': nan,
#   'Pre-direction': nan,
#   'Street name of work location': nan,
#   'Street Suffix': nan,
#   'Post-direction': nan,
#   'City': nan,
#   'State': nan,
#   'ZIP code': nan},
#  {'Service Request Number': 200138616,
#   'Request Type': 'S15',
#   'Description': 'SIGNS-OTHER VIOLATIONS',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': '3511 University Ave, Kensington Md.',
#   'Street Number': '3511',
#   'Pre-direction': 'W',
#   'Street name of work location': 'UNIVERSITY',
#   'Street Suffix': 'BLVD',
#   'Post-direction': nan,
#   'City': 'KENSINGTON',
#   'State': 'MD',
#   'ZIP code': 20895.0},
#  {'Service Request Number': 200138617,
#   'Request Type': 'RW4',
#   'Description': 'OBSTRUCTION IN ROW (DUMPSTER, MONUMENT MAILBOX & TREES)',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'LEFER',
#   'Inspection Date': nan,
#   'Location': '18625 Mooney Dr BLOCKING THE ROAD',
#   'Street Number': '18625',
#   'Pre-direction': nan,
#   'Street name of work location': 'MOONEY',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20879.0},
#  {'Service Request Number': 200138618,
#   'Request Type': 'S10',
#   'Description': 'NO PERMIT FOR SIGN',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'VARGA',
#   'Inspection Date': nan,
#   'Location': 'There are numerous "bandit signs" placed cross Burtonsville, MD. These were placed by the owner Adel of Adels Braids. Please fine them or stop them from them performing the illegal placement of signs in common areas.3822 Swan House Ct, Burtonsville, MD 20866',
#   'Street Number': '3822',
#   'Pre-direction': nan,
#   'Street name of work location': 'SWAN HOUSE',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'BURTONSVILLE',
#   'State': 'MD',
#   'ZIP code': 20866.0},
#  {'Service Request Number': 200138619,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/03/2026',
#   'Taken By': 'SCHRA',
#   'Inspector': 'SCHRA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '4610',
#   'Pre-direction': nan,
#   'Street name of work location': 'RENN',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20853.0},
#  {'Service Request Number': 200138620,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/03/2026',
#   'Taken By': 'SCHRA',
#   'Inspector': 'SCHRA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '14132',
#   'Pre-direction': nan,
#   'Street name of work location': 'WHISPERING PINES',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20906.0},
#  {'Service Request Number': 200138621,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/03/2026',
#   'Taken By': 'SCHRA',
#   'Inspector': 'SCHRA',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '13908',
#   'Pre-direction': nan,
#   'Street name of work location': 'NEW HAMPSHIRE',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20904.0},
#  {'Service Request Number': 200138622,
#   'Request Type': 'HO14',
#   'Description': 'HOME OCCUPATION-OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'EKEYI',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '307',
#   'Pre-direction': nan,
#   'Street name of work location': 'SCOTT',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20904.0},
#  {'Service Request Number': 200138623,
#   'Request Type': 'ZZ99',
#   'Description': 'OTHER',
#   'Request Date': '02/03/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9',
#   'Pre-direction': nan,
#   'Street name of work location': 'TRAILRIDGE',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'POTOMAC',
#   'State': 'MD',
#   'ZIP code': 20854.0},
#  {'Service Request Number': 200138624,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/04/2026',
#   'Taken By': 'LEWIK',
#   'Inspector': 'TOTHS',
#   'Inspection Date': nan,
#   'Location': 'Courtyard by Marriott - Chevy Chase',
#   'Street Number': '5520',
#   'Pre-direction': nan,
#   'Street name of work location': 'WISCONSIN',
#   'Street Suffix': 'AVE',
#   'Post-direction': nan,
#   'City': 'CHEVY CHASE',
#   'State': 'MD',
#   'ZIP code': 20815.0},
#  {'Service Request Number': 200138568,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'THORN',
#   'Inspector': 'THORN',
#   'Inspection Date': nan,
#   'Location': 'Apt B',
#   'Street Number': '12908',
#   'Pre-direction': nan,
#   'Street name of work location': 'CHURCHILL RIDGE',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'GERMANTOWN',
#   'State': 'MD',
#   'ZIP code': 20874.0},
#  {'Service Request Number': 200138569,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'THORN',
#   'Inspector': 'THORN',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '12231',
#   'Pre-direction': nan,
#   'Street name of work location': 'ELM FOREST',
#   'Street Suffix': 'CT',
#   'Post-direction': nan,
#   'City': 'CLARKSBURG',
#   'State': 'MD',
#   'ZIP code': 20871.0},
#  {'Service Request Number': 200138570,
#   'Request Type': 'RW7',
#   'Description': 'WIRES (DOWNED/UNSECURED)',
#   'Request Date': '02/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': 'STAUJ',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '9601',
#   'Pre-direction': nan,
#   'Street name of work location': 'ALTA VISTA',
#   'Street Suffix': 'TER',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20814.0},
#  {'Service Request Number': 200138571,
#   'Request Type': 'REFRD',
#   'Description': 'NOT A DPS ISSUE - REFERRED TO ANOTHER DEPT/AGENCY',
#   'Request Date': '02/02/2026',
#   'Taken By': 'WEB',
#   'Inspector': nan,
#   'Inspection Date': nan,
#   'Location': 'Falkland Chase Apartments',
#   'Street Number': '8305',
#   'Pre-direction': nan,
#   'Street name of work location': '16TH',
#   'Street Suffix': 'ST',
#   'Post-direction': nan,
#   'City': 'SILVER SPRING',
#   'State': 'MD',
#   'ZIP code': 20910.0},
#  {'Service Request Number': 200138572,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'THORN',
#   'Inspector': 'THORN',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '6401',
#   'Pre-direction': nan,
#   'Street name of work location': 'ROCK FOREST',
#   'Street Suffix': 'DR',
#   'Post-direction': nan,
#   'City': 'BETHESDA',
#   'State': 'MD',
#   'ZIP code': 20817.0},
#  {'Service Request Number': 200138573,
#   'Request Type': 'FM05',
#   'Description': 'DROP BY',
#   'Request Date': '02/02/2026',
#   'Taken By': 'WILLV',
#   'Inspector': 'WILLV',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '12100',
#   'Pre-direction': nan,
#   'Street name of work location': 'DARNESTOWN',
#   'Street Suffix': 'RD',
#   'Post-direction': nan,
#   'City': 'GAITHERSBURG',
#   'State': 'MD',
#   'ZIP code': 20878.0},
#  {'Service Request Number': 200138574,
#   'Request Type': 'FM04',
#   'Description': 'ON-CALL RESPONSE',
#   'Request Date': '02/02/2026',
#   'Taken By': 'THORN',
#   'Inspector': 'THORN',
#   'Inspection Date': nan,
#   'Location': nan,
#   'Street Number': '10201',
#   'Pre-direction': nan,
#   'Street name of work location': 'GROSVENOR',
#   'Street Suffix': 'PL',
#   'Post-direction': nan,
#   'City': 'ROCKVILLE',
#   'State': 'MD',
#   'ZIP code': 20852.0}]

# %%
# Investigate the data

# What's the data type
type(service_requests)
# Out:
# list

# %%
# How many elements are in the list?
len(service_requests)
# Out:
# 497

# %%
# What does the first element contain?
service_requests[0]
# Out:
# {'Service Request Number': 200138064,
#  'Request Type': 'FM04',
#  'Description': 'ON-CALL RESPONSE',
#  'Request Date': '01/01/2026',
#  'Taken By': 'TOTHS',
#  'Inspector': 'TOTHS',
#  'Inspection Date': nan,
#  'Location': nan,
#  'Street Number': '804',
#  'Pre-direction': nan,
#  'Street name of work location': 'LOWANDER',
#  'Street Suffix': 'LN',
#  'Post-direction': nan,
#  'City': 'SILVER SPRING',
#  'State': 'MD',
#  'ZIP code': 20901.0}

# %%
service_requests[143]
# Out:
# {'Service Request Number': 200138249,
#  'Request Type': 'FM04',
#  'Description': 'ON-CALL RESPONSE',
#  'Request Date': '01/12/2026',
#  'Taken By': 'POLIC',
#  'Inspector': 'POLIC',
#  'Inspection Date': nan,
#  'Location': nan,
#  'Street Number': '13230',
#  'Pre-direction': nan,
#  'Street name of work location': 'CLOPPERS MILL',
#  'Street Suffix': 'DR',
#  'Post-direction': nan,
#  'City': 'GERMANTOWN',
#  'State': 'MD',
#  'ZIP code': 20874.0}

# %%
# 1. How many times did each type of request get made?
#Create a dictionary
request_type_count = {}

#Loop through the Request Type in the service_request data
for  request in service_requests:
    request_type = request["Request Type"]

#If a Request Type is in the dictionary, add 1 to the existing count
    if request_type in request_type_count:
        request_type_count[request_type] += 1

#If a Request Type is not in the dictionary, add it to the dictionary with a value of 1
    else:
        request_type_count[request_type] = 1

print(request_type_count)
# Out:
# {'FM04': 61, 'B12': 10, 'REFRD': 40, 'Z14': 11, 'FM03': 15, 'RW2': 8, 'FM05': 68, 'Z22': 5, 'B10': 22, 'Z30': 15, 'RW1': 14, 'ZZ99': 58, 'Z25': 3, 'WR1': 12, 'RW4': 11, 'FM01': 2, 'DA10': 1, 'S10': 6, 'LD1': 3, 'B11': 9, 'Z13': 3, 'WR3': 4, 'RW5': 11, 'FM02': 3, 'S': 6, 'Z28': 4, 'RW7': 17, 'B14': 6, 'A10': 1, 'Z99': 18, 'Z15': 1, 'Z21': 2, 'WR': 2, 'B': 6, 'Z20': 2, 'S11': 2, 'HO14': 9, 'HO': 3, 'Z11': 1, 'Z18': 1, 'HO10': 3, 'WR2': 2, 'Z17': 1, 'HO13': 2, 'WR5': 3, 'Z': 2, 'Z26': 2, 'V10': 1, 'BEM10': 1, 'WS3': 1, 'HO11': 1, 'B20': 1, 'S15': 1}

# %%
# 2. How many times did requests get made from each city?
# Make an empty dictionary
city_request_count = {}

#Loop through each City in service_request
for city in service_requests:
    city_request = city["City"]

#If a city is already in the dictionary, add 1 to its existing count
    if city_request in city_request_count:
        city_request_count[city_request] += 1

#If a city is not in the dictionary, add it to the dictionary with a value of 1
    else:
        city_request_count[city_request] = 1

print(city_request_count)
# Out:
# {'SILVER SPRING': 114, 'ROCKVILLE': 72, 'DAMASCUS': 8, 'TAKOMA PARK': 9, 'BETHESDA': 50, nan: 94, 'GAITHERSBURG': 37, 'CHEVY CHASE': 16, 'KENSINGTON': 20, 'GERMANTOWN': 29, 'POOLESVILLE': 2, 'DICKERSON': 2, 'BURTONSVILLE': 2, 'POTOMAC': 13, 'CLARKSBURG': 9, 'BOYDS': 3, 'OLNEY': 10, 'MONTGOMERY VILLAGE': 1, 'BEALLSVILLE': 3, 'SANDY SPRING': 2, 'SPENCERVILLE': 1}
