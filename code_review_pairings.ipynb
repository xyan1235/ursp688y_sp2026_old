# %%
import random

# %%
def chunks(_list, chunk_length=2, seed=False):
    """Return randomized chunks of the input list with a specified minimum length.
    Adapted from https://stackoverflow.com/questions/24483182/python-split-list-into-n-chunks
    """
    if seed:
        random.seed(seed)
    # Ensure list elements are randomized
    random.shuffle(students)
    # Determine the number of chunks necessary given the specified chunk length
    n_chunks = len(_list) // chunk_length
    # Break the list into chunks and store them in another list
    chunks = []
    for i in range(0, n_chunks):
        chunks.append(_list[i::n_chunks])
    return chunks

# %%
students = [
    'Colin',
    'Derek',
    'Dominic',
    'Emmanuel',
    'Finn',
    'Joseph',
    'Noah',
    'Siddhi',  
    'Xuedi',
]

chunks(students, chunk_length=2, seed=3)
# Out:
# [['Derek', 'Xuedi', 'Emmanuel'],
#  ['Joseph', 'Finn'],
#  ['Noah', 'Siddhi'],
#  ['Colin', 'Dominic']]

# %% [markdown]
# Exercise 1:
#
# - Group 1: Joseph, Emmanuel, Dominic
#
# - Group 2: Noah, Colin
#
# - Group 3: Siddhi, Xuedi
#
# - Group 4: Finn, Derek
#
# Exercise 2:
#
# - Group 1: Emmanuel, Siddhi, Colin (Emmanuel reviews Siddhi, Siddi reviews Colin, Colin reviews Emmanuel)
#
# - Group 2: Noah, Dominic
#
# - Group 3: Finn, Xuedi
#
# - Group 4: Joseph, Derek
#
# Exercise 3:
#
# - Group 1: Derek, Xuedi, Emmanuel (Derek reviews Xuedi, Xuedi reviews Emmanuel, Emmanuel reviews Derek)
#
# - Group 2: Joseph, Finn
#
# - Group 3: Noah, Siddhi
#
# - Group 4: Colin, Dominic
